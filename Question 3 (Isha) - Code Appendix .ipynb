# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv("all_years_updated_chicago_results.csv")
df
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2450260484.py:1: DtypeWarning: Columns (4,5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("all_years_updated_chicago_results.csv")
#         index  place_overall  gender_place                  name_ctz  \
# 0          14            1.0           1.0       Kimondiu, Ben (KEN)
# 1          22            2.0           2.0        Tergat, Paul (KEN)
# 2          18            3.0           3.0      Githuka, Peter (KEN)
# 3          20            4.0           4.0     Ouaadi, Mohamed (FRA)
# 4          14            5.0           5.0   Igarashi, Noriaki (JPN)
# ...       ...            ...           ...                       ...
# 885965  60056            NaN           NaN     Zwick, Caroline (USA)
# 885966  60060            NaN           NaN          Zybak, Don (USA)
# 885967  60065            NaN           NaN          Zyck, Kyle (USA)
# ...

# %%
df1 = df[(df['year'] == 2023) | (df['year'] == 2017)]     #year 2023 or 2017
df1
# Out:
#         index  place_overall  gender_place                  name_ctz  \
# 575830     14            1.0           1.0         Rupp, Galen (USA)
# 575831     23            2.0           2.0         Kirui, Abel (KEN)
# 575832      3            3.0           3.0    Kipyego, Bernard (KEN)
# 575833     18            4.0           4.0        Lemma, Sisay (ETH)
# 575834      3            5.0           5.0      Sambu, Stephen (KEN)
# ...       ...            ...           ...                       ...
# 885965  60056            NaN           NaN     Zwick, Caroline (USA)
# 885966  60060            NaN           NaN          Zybak, Don (USA)
# 885967  60065            NaN           NaN          Zyck, Kyle (USA)
# 885968  60067            NaN           NaN  Zymantas, Jennifer (USA)
# 885969  60071            NaN           NaN       Zyvert, Laura (USA)
#
#            event    bib division final_time marathon  year gender half_time
# ...

# %%
df1[df1['name_ctz'] == "Smith, Matthew (USA)"]   #duplicate names
# Out:
#         index  place_overall  gender_place              name_ctz     event  \
# 577481     11         1652.0        1464.0  Smith, Matthew (USA)  Marathon
# 578868     12         3040.0        2603.0  Smith, Matthew (USA)  Marathon
# 580211     13         4383.0        3585.0  Smith, Matthew (USA)  Marathon
# 609264     10        33436.0       18712.0  Smith, Matthew (USA)  Marathon
# 828391  50263         2494.0        2271.0  Smith, Matthew (USA)       NaN
# 856378  50261        30483.0       18666.0  Smith, Matthew (USA)       NaN
# 860988  50260        35094.0       20637.0  Smith, Matthew (USA)       NaN
# 871878  50262        45987.0       24956.0  Smith, Matthew (USA)       NaN
#
#           bib division final_time marathon  year gender half_time
# 577481   9277    40-44   03:09:40  chicago  2017      M       NaN
# 578868  18023    30-34   03:22:25  chicago  2017      M       NaN
# 580211  18024    25-29   03:30:53  chicago  2017      M       NaN
# ...

# %%
duplicate_runners = pd.merge(before, after, on = 'name_ctz', how = 'inner')['name_ctz'].to_list()  #identify duplicates runners

# %%
df2 = df1[~df1['name_ctz'].isin(duplicate_runners)]  #remove duplicates
df2
# Out:
#         index  place_overall  gender_place                  name_ctz  \
# 575831     23            2.0           2.0         Kirui, Abel (KEN)
# 575832      3            3.0           3.0    Kipyego, Bernard (KEN)
# 575833     18            4.0           4.0        Lemma, Sisay (ETH)
# 575834      3            5.0           5.0      Sambu, Stephen (KEN)
# 575835      4            6.0           6.0   Matsumura , Kohei (JPN)
# ...       ...            ...           ...                       ...
# 885965  60056            NaN           NaN     Zwick, Caroline (USA)
# 885966  60060            NaN           NaN          Zybak, Don (USA)
# 885967  60065            NaN           NaN          Zyck, Kyle (USA)
# 885968  60067            NaN           NaN  Zymantas, Jennifer (USA)
# 885969  60071            NaN           NaN       Zyvert, Laura (USA)
#
#            event    bib division final_time marathon  year gender half_time
# ...

# %%
before_unique = before[~before['name_ctz'].isin(duplicate_runners)]   #remove duplicates

# %%
before_unique
# Out:
#         index  place_overall  gender_place                 name_ctz     event  \
# 575831     23            2.0           2.0        Kirui, Abel (KEN)  Marathon
# 575832      3            3.0           3.0   Kipyego, Bernard (KEN)  Marathon
# 575833     18            4.0           4.0       Lemma, Sisay (ETH)  Marathon
# 575834      3            5.0           5.0     Sambu, Stephen (KEN)  Marathon
# 575835      4            6.0           6.0  Matsumura , Kohei (JPN)  Marathon
# ...       ...            ...           ...                      ...       ...
# 620155     13        44328.0       22820.0  McDonough, Robert (USA)  Marathon
# 620161      6        44334.0       22821.0      Lammel, Derek (USA)  Marathon
# 620164      2        44337.0       22822.0      Antonini, Joe (USA)  Marathon
# 620169      3        44342.0       22823.0     Mburu, Kamunyu (USA)  Marathon
# 620176      8        44349.0       22824.0     Gallo, Gregory (USA)  Marathon
#
# ...

# %%
after_unique = after[~after['name_ctz'].isin(duplicate_runners)]

# %%
after_unique
# Out:
#         index  place_overall  gender_place                      name_ctz  \
# 825898  27371            1.0           1.0          Kiptum, Kelvin (KEN)
# 825899  27369            2.0           2.0         Kipruto, Benson (KEN)
# 825900     72            3.0           3.0            Abdi, Bashir (BEL)
# 825901  27970            4.0           4.0             Korir, John (KEN)
# 825902  54366            5.0           5.0     Tura Abdiwak, Seifu (ETH)
# ...       ...            ...           ...                           ...
# 874299  42370        48408.0       22531.0         Pirro, Vivianne (USA)
# 874300  44953        48409.0       22532.0          Riley, Felicia (USA)
# 874301  28156        48410.0       22533.0         Krajewski, Rose (USA)
# 874302  59185        48411.0       22534.0         Young, Jeanette (USA)
# 874307   1629        48416.0       22535.0  Anizar, Elvis Febriani (INA)
#
#        event    bib division final_time marathon  year gender half_time
# ...

# %%
a1 = df2[(df2['year'] == 2023) & (df2['gender']=='M')]
a1
# Out:
#         index  place_overall  gender_place                      name_ctz  \
# 825898  27371            1.0           1.0          Kiptum, Kelvin (KEN)
# 825899  27369            2.0           2.0         Kipruto, Benson (KEN)
# 825900     72            3.0           3.0            Abdi, Bashir (BEL)
# 825901  27970            4.0           4.0             Korir, John (KEN)
# 825902  54366            5.0           5.0     Tura Abdiwak, Seifu (ETH)
# ...       ...            ...           ...                           ...
# 874299  42370        48408.0       22531.0         Pirro, Vivianne (USA)
# 874300  44953        48409.0       22532.0          Riley, Felicia (USA)
# 874301  28156        48410.0       22533.0         Krajewski, Rose (USA)
# 874302  59185        48411.0       22534.0         Young, Jeanette (USA)
# 874307   1629        48416.0       22535.0  Anizar, Elvis Febriani (INA)
#
#        event    bib division final_time marathon  year gender half_time
# ...

# %%
a1['final_time'] = pd.to_datetime(a1['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/151234713.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   a1['final_time'] = pd.to_datetime(a1['final_time'])
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/151234713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a1['final_time'] = pd.to_datetime(a1['final_time'])

# %%
a1['final_time'].median()
# Out:
# Timestamp('2024-03-04 04:14:31')

# %%
a1['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:24:30.584822016')

# %%
a1['final_time'].min()
# Out:
# Timestamp('2024-03-04 02:00:35')

# %%
b1 = df2[(df2['year'] == 2017) & (df2['gender']=='M')]
b1
# Out:
#         index  place_overall  gender_place                 name_ctz     event  \
# 575831     23            2.0           2.0        Kirui, Abel (KEN)  Marathon
# 575832      3            3.0           3.0   Kipyego, Bernard (KEN)  Marathon
# 575833     18            4.0           4.0       Lemma, Sisay (ETH)  Marathon
# 575834      3            5.0           5.0     Sambu, Stephen (KEN)  Marathon
# 575835      4            6.0           6.0  Matsumura , Kohei (JPN)  Marathon
# ...       ...            ...           ...                      ...       ...
# 620155     13        44328.0       22820.0  McDonough, Robert (USA)  Marathon
# 620161      6        44334.0       22821.0      Lammel, Derek (USA)  Marathon
# 620164      2        44337.0       22822.0      Antonini, Joe (USA)  Marathon
# 620169      3        44342.0       22823.0     Mburu, Kamunyu (USA)  Marathon
# 620176      8        44349.0       22824.0     Gallo, Gregory (USA)  Marathon
#
# ...

# %%
b1['final_time'] = pd.to_datetime(b1['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2475532855.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   b1['final_time'] = pd.to_datetime(b1['final_time'])
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2475532855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b1['final_time'] = pd.to_datetime(b1['final_time'])

# %%
b1['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:33:09.283781376')

# %%
a1['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:24:30.584822016')

# %%
a1['seconds'] = pd.to_timedelta(a1['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/3042126230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a1['seconds'] = pd.to_timedelta(a1['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
b1['seconds'] = pd.to_timedelta(b1['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2716647004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b1['seconds'] = pd.to_timedelta(b1['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
np.var(b1['seconds']) #unequal variances
# Out:
# 12972455.748076387

# %%
np.var(a1['seconds'])   #unequal variances
# Out:
# 13970897.667337568

# %%
print(stats.ttest_ind(b1['seconds'], a1['seconds'], equal_var = False))
# Out:
# Ttest_indResult(statistic=15.046280178356973, pvalue=4.854793968628957e-51)

# %%
after_f = df[(df['year'] == 2023) & (df['gender'] == 'F')]
before_f = df[(df['year'] == 2017) & (df['gender'] == 'F')]

# %%
duplicate_runners_f = pd.merge(before_f, after_f, on = 'name_ctz', how = 'inner')['name_ctz'].to_list()

# %%
len(duplicate_runners_f)/ len(before_f)
# Out:
# 0.030985784632537396

# %%
len(duplicate_runners)/ len(df1)
# Out:
# 0.009790466533213284

# %%
before_unique_f = before_f[~before_f['name_ctz'].isin(duplicate_runners_f)]
after_unique_f = after_f[~after_f['name_ctz'].isin(duplicate_runners_f)]

# %%
before_unique_f['final_time'] = pd.to_datetime(before_unique_f['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/395013772.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   before_unique_f['final_time'] = pd.to_datetime(before_unique_f['final_time'])
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/395013772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_unique_f['final_time'] = pd.to_datetime(before_unique_f['final_time'])

# %%
after_unique_f['final_time'] = pd.to_datetime(after_unique_f['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2799952772.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   after_unique_f['final_time'] = pd.to_datetime(after_unique_f['final_time'])
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2799952772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after_unique_f['final_time'] = pd.to_datetime(after_unique_f['final_time'])

# %%
before_unique_f['final_time'].mean()
# Out:
# Timestamp('2024-03-04 05:03:17.678532096')

# %%
after_unique_f['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:16:56.633867264')

# %%
after_unique_f['seconds'] = pd.to_timedelta(after_unique_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/1729668779.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after_unique_f['seconds'] = pd.to_timedelta(after_unique_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
before_unique_f['seconds'] = pd.to_timedelta(before_unique_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2832972869.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_unique_f['seconds'] = pd.to_timedelta(before_unique_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
print(stats.ttest_ind(before_unique_f['seconds'], after_unique_f['seconds'], equal_var = False))
# Out:
# Ttest_indResult(statistic=81.8811943712643, pvalue=0.0)

# %%
after
# Out:
#         index  place_overall  gender_place                      name_ctz  \
# 825898  27371            1.0           1.0          Kiptum, Kelvin (KEN)
# 825899  27369            2.0           2.0         Kipruto, Benson (KEN)
# 825900     72            3.0           3.0            Abdi, Bashir (BEL)
# 825901  27970            4.0           4.0             Korir, John (KEN)
# 825902  54366            5.0           5.0     Tura Abdiwak, Seifu (ETH)
# ...       ...            ...           ...                           ...
# 874299  42370        48408.0       22531.0         Pirro, Vivianne (USA)
# 874300  44953        48409.0       22532.0          Riley, Felicia (USA)
# 874301  28156        48410.0       22533.0         Krajewski, Rose (USA)
# 874302  59185        48411.0       22534.0         Young, Jeanette (USA)
# 874307   1629        48416.0       22535.0  Anizar, Elvis Febriani (INA)
#
#        event    bib division final_time marathon  year gender half_time
# ...

# %%
before
# Out:
#         index  place_overall  gender_place                 name_ctz     event  \
# 575830     14            1.0           1.0        Rupp, Galen (USA)  Marathon
# 575831     23            2.0           2.0        Kirui, Abel (KEN)  Marathon
# 575832      3            3.0           3.0   Kipyego, Bernard (KEN)  Marathon
# 575833     18            4.0           4.0       Lemma, Sisay (ETH)  Marathon
# 575834      3            5.0           5.0     Sambu, Stephen (KEN)  Marathon
# ...       ...            ...           ...                      ...       ...
# 620155     13        44328.0       22820.0  McDonough, Robert (USA)  Marathon
# 620161      6        44334.0       22821.0      Lammel, Derek (USA)  Marathon
# 620164      2        44337.0       22822.0      Antonini, Joe (USA)  Marathon
# 620169      3        44342.0       22823.0     Mburu, Kamunyu (USA)  Marathon
# 620176      8        44349.0       22824.0     Gallo, Gregory (USA)  Marathon
#
# ...

# %%
after["time"] = after["final_time"].map(lambda x: x.strftime("%H:%M"))
plt.figure(figsize=(16,6))
plt.xticks(np.arange(0, len(after["time"]) + 1, 100))
plt.hist(after["time"], bins = 40, edgecolor = 'black')
plt.xlabel('Time', fontsize = 20)
plt.ylabel('Counts', fontsize = 20)
plt.title("Distribution of 2023 Men Chicago Marathon Times", fontsize = 20)
plt.grid()
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/960942876.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after["time"] = after["final_time"].map(lambda x: x.strftime("%H:%M"))

# %%
after_f["time"] = after_f["final_time"].map(lambda x: x.strftime("%H:%M"))
plt.figure(figsize=(16,6))
plt.xticks(np.arange(0, len(after_f["time"]) + 1, 100))
plt.hist(after_f["time"], bins = 40, edgecolor = 'black', color = 'orange')
plt.xlabel('Time', fontsize = 20)
plt.ylabel('Counts', fontsize = 20)
plt.title("Distribution of 2023 Women Chicago Marathon Times", fontsize = 20)
plt.grid()
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/1818865350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after_f["time"] = after_f["final_time"].map(lambda x: x.strftime("%H:%M"))

# %%
before_f["time"] = before_f["final_time"].map(lambda x: x.strftime("%H:%M"))
plt.figure(figsize=(16,6))
plt.xticks(np.arange(0, len(before_f["time"]) + 1, 100))
plt.hist(before_f["time"], bins = 40, edgecolor = 'black', color = 'orange')
plt.xlabel('Time', fontsize = 20)
plt.ylabel('Counts', fontsize = 20)
plt.title("Distribution of 2017 Women Chicago Marathon Times", fontsize = 20)
plt.grid()
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/4137159145.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_f["time"] = before_f["final_time"].map(lambda x: x.strftime("%H:%M"))

# %%
before["time"] = before["final_time"].map(lambda x: x.strftime("%H:%M"))
plt.figure(figsize=(16,6))
plt.xticks(np.arange(0, len(before["time"]) + 1, 100))
plt.hist(before["time"], bins = 40, edgecolor = 'black')
plt.xlabel('Time', fontsize = 20)
plt.ylabel('Counts', fontsize = 20)
plt.title("Distribution of 2017 Men Chicago Marathon Times", fontsize = 20)
plt.grid()
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/3349552977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before["time"] = before["final_time"].map(lambda x: x.strftime("%H:%M"))

# %%
before.drop_duplicates(subset = 'name_ctz').dropna(subset = 'final_time', inplace = True)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/19296813.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before.drop_duplicates(subset = 'name_ctz').dropna(subset = 'final_time', inplace = True)

# %%
after_unique
# Out:
#         index  place_overall  gender_place                      name_ctz  \
# 825898  27371            1.0           1.0          Kiptum, Kelvin (KEN)
# 825899  27369            2.0           2.0         Kipruto, Benson (KEN)
# 825900     72            3.0           3.0            Abdi, Bashir (BEL)
# 825901  27970            4.0           4.0             Korir, John (KEN)
# 825902  54366            5.0           5.0     Tura Abdiwak, Seifu (ETH)
# ...       ...            ...           ...                           ...
# 874299  42370        48408.0       22531.0         Pirro, Vivianne (USA)
# 874300  44953        48409.0       22532.0          Riley, Felicia (USA)
# 874301  28156        48410.0       22533.0         Krajewski, Rose (USA)
# 874302  59185        48411.0       22534.0         Young, Jeanette (USA)
# 874307   1629        48416.0       22535.0  Anizar, Elvis Febriani (INA)
#
#        event    bib division final_time marathon  year gender half_time
# ...

# %%
after_unique.drop_duplicates(subset = 'name_ctz')
# Out:
#         index  place_overall  gender_place                      name_ctz  \
# 825898  27371            1.0           1.0          Kiptum, Kelvin (KEN)
# 825899  27369            2.0           2.0         Kipruto, Benson (KEN)
# 825900     72            3.0           3.0            Abdi, Bashir (BEL)
# 825901  27970            4.0           4.0             Korir, John (KEN)
# 825902  54366            5.0           5.0     Tura Abdiwak, Seifu (ETH)
# ...       ...            ...           ...                           ...
# 874299  42370        48408.0       22531.0         Pirro, Vivianne (USA)
# 874300  44953        48409.0       22532.0          Riley, Felicia (USA)
# 874301  28156        48410.0       22533.0         Krajewski, Rose (USA)
# 874302  59185        48411.0       22534.0         Young, Jeanette (USA)
# 874307   1629        48416.0       22535.0  Anizar, Elvis Febriani (INA)
#
#        event    bib division final_time marathon  year gender half_time
# ...

# %%
1 - (len(after_unique)/len(after))
# Out:
# 0.04286177280829684

# %%
1 - (len(before_unique)/len(before))
# Out:
# 0.04797791701353893

# %%
1 - (len(before_unique_f)/len(before_f))
# Out:
# 0.03033540834339865

# %%
after['final_time'] = pd.to_datetime(after['final_time'])
before['final_time'] = pd.to_datetime(before['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/151652193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after['final_time'] = pd.to_datetime(after['final_time'])
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/151652193.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before['final_time'] = pd.to_datetime(before['final_time'])

# %%
after['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:24:06.860760064')

# %%
before['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:32:42.753362688')

# %%
before['seconds'] = pd.to_timedelta(before['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/871740839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before['seconds'] = pd.to_timedelta(before['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
after['seconds'] = pd.to_timedelta(after['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2174730252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after['seconds'] = pd.to_timedelta(after['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
print(stats.ttest_ind(before['seconds'], after['seconds'], equal_var = False))
# Out:
# Ttest_indResult(statistic=15.347576952653677, pvalue=4.933364733120725e-53)

# %%
after_f['final_time'] = pd.to_datetime(after_f['final_time'])
before_f['final_time'] = pd.to_datetime(before_f['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/3414783236.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   after_f['final_time'] = pd.to_datetime(after_f['final_time'])
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/3414783236.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after_f['final_time'] = pd.to_datetime(after_f['final_time'])
# ...

# %%
after_f['final_time'].mean()
# Out:
# Timestamp('2024-03-04 04:17:24.450939648')

# %%
before_f['final_time'].mean()
# Out:
# Timestamp('2024-03-04 05:02:47.969896960')

# %%
before_f['seconds'] = pd.to_timedelta(before_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/2794966335.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   before_f['seconds'] = pd.to_timedelta(before_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
after_f['seconds'] = pd.to_timedelta(after_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/3796253477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after_f['seconds'] = pd.to_timedelta(after_f['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
print(stats.ttest_ind(before_f['seconds'], after_f['seconds'], equal_var = False))
# Out:
# Ttest_indResult(statistic=81.41515622098184, pvalue=0.0)

# %%
 # Importing libraries 
import scipy.stats as stats 
import numpy as np

# %%
df_clean = df.loc[:,['final_time', 'year', 'gender']].dropna()

# %%
df_clean = df_clean[df_clean['final_time'] != "PND"]
df_clean
# Out:
#        final_time  year gender
# 0        02:08:52  2001      M
# 1        02:08:56  2001      M
# 2        02:09:00  2001      M
# 3        02:09:26  2001      M
# 4        02:09:35  2001      M
# ...           ...   ...    ...
# 874303   09:00:29  2023      F
# 874304   09:17:20  2023      F
# 874305   09:18:19  2023      F
# 874306   09:19:32  2023      F
# 874307   09:41:14  2023      M
#
# [797666 rows x 3 columns]

# %%
df_clean['final_time'] = pd.to_datetime(df_clean['final_time'])
# Out:
# /var/folders/cc/0rm56zcd02s51nm3n6yntq980000gn/T/ipykernel_26087/3473137164.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_clean['final_time'] = pd.to_datetime(df_clean['final_time'])

# %%
df_clean['normal'] = df_clean['final_time'].dt.normalize()

# %%
df_clean
# Out:
#                 final_time  year gender     normal
# 0      2024-03-12 02:08:52  2001      M 2024-03-12
# 1      2024-03-12 02:08:56  2001      M 2024-03-12
# 2      2024-03-12 02:09:00  2001      M 2024-03-12
# 3      2024-03-12 02:09:26  2001      M 2024-03-12
# 4      2024-03-12 02:09:35  2001      M 2024-03-12
# ...                    ...   ...    ...        ...
# 874303 2024-03-12 09:00:29  2023      F 2024-03-12
# 874304 2024-03-12 09:17:20  2023      F 2024-03-12
# 874305 2024-03-12 09:18:19  2023      F 2024-03-12
# 874306 2024-03-12 09:19:32  2023      F 2024-03-12
# 874307 2024-03-12 09:41:14  2023      M 2024-03-12
#
# [797666 rows x 4 columns]

# %%
df_clean['time'] = df_clean['final_time'] - df_clean['final_time'].dt.normalize()

# %%
df_clean
# Out:
#                 final_time  year gender     normal            time
# 0      2024-03-12 02:08:52  2001      M 2024-03-12 0 days 02:08:52
# 1      2024-03-12 02:08:56  2001      M 2024-03-12 0 days 02:08:56
# 2      2024-03-12 02:09:00  2001      M 2024-03-12 0 days 02:09:00
# 3      2024-03-12 02:09:26  2001      M 2024-03-12 0 days 02:09:26
# 4      2024-03-12 02:09:35  2001      M 2024-03-12 0 days 02:09:35
# ...                    ...   ...    ...        ...             ...
# 874303 2024-03-12 09:00:29  2023      F 2024-03-12 0 days 09:00:29
# 874304 2024-03-12 09:17:20  2023      F 2024-03-12 0 days 09:17:20
# 874305 2024-03-12 09:18:19  2023      F 2024-03-12 0 days 09:18:19
# 874306 2024-03-12 09:19:32  2023      F 2024-03-12 0 days 09:19:32
# 874307 2024-03-12 09:41:14  2023      M 2024-03-12 0 days 09:41:14
#
# [797666 rows x 5 columns]

# %%
df_female = df_clean[df_clean['gender'] == "F"]

# %%
df_male = df_clean[df_clean['gender'] == "M"]

# %%
df_clean.groupby(['gender', 'year'])['final_time'].mean()
# Out:
# gender  year
# F       2001   2024-03-12 04:35:53.363124480
#         2002   2024-03-12 04:36:07.584783616
#         2003   2024-03-12 04:41:51.010752000
#         2004   2024-03-12 04:42:36.367898112
#         2005   2024-03-12 04:41:06.440678144
#         2006   2024-03-12 04:41:12.903905024
#         2007   2024-03-12 04:52:39.517422848
#         2008   2024-03-12 05:00:31.041782528
#         2009   2024-03-12 04:43:21.430456832
#         2010   2024-03-12 04:58:55.390520320
#         2011   2024-03-12 04:55:54.514091776
#         2012   2024-03-12 04:47:51.724333056
#         2013   2024-03-12 04:46:37.059855104
#         2014   2024-03-12 04:48:11.097957120
#         2015   2024-03-12 04:48:01.565517056
#         2016   2024-03-12 04:50:03.251943424
#         2017   2024-03-12 05:02:47.969896960
#         2018   2024-03-12 04:50:14.194776832
#         2019   2024-03-12 04:46:53.246971136
#         2021   2024-03-12 04:57:19.681232640
# ...

# %%
df_male_ave = df_male.groupby('year')['final_time'].mean()

# %%
df_female_ave = df_female.groupby('year')['final_time'].mean()

# %%
male = df_male_ave.to_frame()
male
# Out:
#                         final_time
# year
# 2001 2024-03-12 04:08:43.427168256
# 2002 2024-03-12 04:08:10.247009024
# 2003 2024-03-12 04:13:16.111771136
# 2004 2024-03-12 04:15:23.308627200
# 2005 2024-03-12 04:15:00.820396800
# 2006 2024-03-12 04:12:31.951298304
# 2007 2024-03-12 04:54:24.728984832
# 2008 2024-03-12 04:35:43.189942784
# 2009 2024-03-12 04:16:07.631435264
# 2010 2024-03-12 04:31:49.714729728
# 2011 2024-03-12 04:29:38.516763648
# 2012 2024-03-12 04:19:38.614767104
# 2013 2024-03-12 04:20:55.989342464
# 2014 2024-03-12 04:20:36.158108160
# 2015 2024-03-12 04:22:51.612770560
# 2016 2024-03-12 04:21:56.255934208
# 2017 2024-03-12 04:32:42.753362944
# 2018 2024-03-12 04:19:55.579625472
# 2019 2024-03-12 04:14:54.378504704
# 2021 2024-03-12 04:30:03.633880064
# 2022 2024-03-12 04:23:43.358667264
# 2023 2024-03-12 04:24:06.860760064

# %%
female = df_female_ave.to_frame()
female
# Out:
#                         final_time
# year
# 2001 2024-03-12 04:35:53.363124480
# 2002 2024-03-12 04:36:07.584783616
# 2003 2024-03-12 04:41:51.010752000
# 2004 2024-03-12 04:42:36.367898112
# 2005 2024-03-12 04:41:06.440678144
# 2006 2024-03-12 04:41:12.903905024
# 2007 2024-03-12 04:52:39.517422848
# 2008 2024-03-12 05:00:31.041782528
# 2009 2024-03-12 04:43:21.430456832
# 2010 2024-03-12 04:58:55.390520320
# 2011 2024-03-12 04:55:54.514091776
# 2012 2024-03-12 04:47:51.724333056
# 2013 2024-03-12 04:46:37.059855104
# 2014 2024-03-12 04:48:11.097957120
# 2015 2024-03-12 04:48:01.565517056
# 2016 2024-03-12 04:50:03.251943424
# 2017 2024-03-12 05:02:47.969896960
# 2018 2024-03-12 04:50:14.194776832
# 2019 2024-03-12 04:46:53.246971136
# 2021 2024-03-12 04:57:19.681232640
# 2022 2024-03-12 04:35:41.985230592
# 2023 2024-03-12 04:17:24.450940160

# %%
male['seconds'] = pd.to_timedelta(male['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
female['seconds'] = pd.to_timedelta(female['final_time'].dt.strftime('%H:%M:%S')).dt.total_seconds().astype(int)

# %%
female
# Out:
#                         final_time  seconds
# year
# 2001 2024-03-12 04:35:53.363124480    16553
# 2002 2024-03-12 04:36:07.584783616    16567
# 2003 2024-03-12 04:41:51.010752000    16911
# 2004 2024-03-12 04:42:36.367898112    16956
# 2005 2024-03-12 04:41:06.440678144    16866
# 2006 2024-03-12 04:41:12.903905024    16872
# 2007 2024-03-12 04:52:39.517422848    17559
# 2008 2024-03-12 05:00:31.041782528    18031
# 2009 2024-03-12 04:43:21.430456832    17001
# 2010 2024-03-12 04:58:55.390520320    17935
# 2011 2024-03-12 04:55:54.514091776    17754
# 2012 2024-03-12 04:47:51.724333056    17271
# 2013 2024-03-12 04:46:37.059855104    17197
# 2014 2024-03-12 04:48:11.097957120    17291
# 2015 2024-03-12 04:48:01.565517056    17281
# 2016 2024-03-12 04:50:03.251943424    17403
# 2017 2024-03-12 05:02:47.969896960    18167
# 2018 2024-03-12 04:50:14.194776832    17414
# 2019 2024-03-12 04:46:53.246971136    17213
# 2021 2024-03-12 04:57:19.681232640    17839
# ...

# %%
male
# Out:
#                         final_time  seconds
# year
# 2001 2024-03-12 04:08:43.427168256    14923
# 2002 2024-03-12 04:08:10.247009024    14890
# 2003 2024-03-12 04:13:16.111771136    15196
# 2004 2024-03-12 04:15:23.308627200    15323
# 2005 2024-03-12 04:15:00.820396800    15300
# 2006 2024-03-12 04:12:31.951298304    15151
# 2007 2024-03-12 04:54:24.728984832    17664
# 2008 2024-03-12 04:35:43.189942784    16543
# 2009 2024-03-12 04:16:07.631435264    15367
# 2010 2024-03-12 04:31:49.714729728    16309
# 2011 2024-03-12 04:29:38.516763648    16178
# 2012 2024-03-12 04:19:38.614767104    15578
# 2013 2024-03-12 04:20:55.989342464    15655
# 2014 2024-03-12 04:20:36.158108160    15636
# 2015 2024-03-12 04:22:51.612770560    15771
# 2016 2024-03-12 04:21:56.255934208    15716
# 2017 2024-03-12 04:32:42.753362944    16362
# 2018 2024-03-12 04:19:55.579625472    15595
# 2019 2024-03-12 04:14:54.378504704    15294
# 2021 2024-03-12 04:30:03.633880064    16203
# ...

# %%
male['seconds'].values
# Out:
# array([14923, 14890, 15196, 15323, 15300, 15151, 17664, 16543, 15367,
#        16309, 16178, 15578, 15655, 15636, 15771, 15716, 16362, 15595,
#        15294, 16203, 15823, 15846])

# %%
year_vals = male.index.values

# %%
plt.plot(year_vals, male['seconds'].values)

# %%
male['year_vals'] = year_vals

# %%
import matplotlib.ticker as tkr
import datetime

def func(x, pos):
    return str(datetime.timedelta(seconds=x))
fmt = tkr.FuncFormatter(func)


ax = male.plot(x='year_vals', y='seconds',
               title = "Average Male Marathon Time from 2001 to 2023 for Chicago Marathon")
#ax.xaxis.set_major_formatter(fmt)
ax.yaxis.set_major_formatter(fmt)
ax.set_ylabel("Average Time")
ax.set_xlabel("Year", fontsize = 20)
ax.grid(visible=True)
ax.legend("")

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
female['year'] = year_vals

# %%
import matplotlib.ticker as tkr
import datetime

def func(x, pos):
    return str(datetime.timedelta(seconds=x))
fmt = tkr.FuncFormatter(func)


ax = female.plot(x='year', y='seconds',
               title = "Average Female Marathon Time from 2001 to 2023 for Chicago Marathon")
#ax.xaxis.set_major_formatter(fmt)
ax.yaxis.set_major_formatter(fmt)
ax.set_ylabel("Average Time")
ax.set_xlabel("Year")
ax.grid(visible=True)
ax.legend("")
